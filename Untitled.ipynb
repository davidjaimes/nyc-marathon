# %%
import pandas as pd
import requests

headers = {
    'origin': 'https://results.nyrr.org',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'content-type': 'application/json;charset=UTF-8',
    'accept': 'application/json, text/plain, */*',
    'referer': 'https://results.nyrr.org/event/791021/finishers',
    'authority': 'results.nyrr.org',
    'cookie': '__cfduid=de36b16bb4d0acc47786cf2b9997d54d71560818244; _gcl_au=1.1.1592280569.1560818247; _ga=GA1.2.190767401.1560818247; _gid=GA1.2.207092622.1560818247; _fbp=fb.1.1560818247391.393523298; ARRAffinity=851d7f30361f6d0723ca121b2bd6d6718ac17eb6e82712885034bbf6fcabc392; _ga=GA1.3.190767401.1560818247; _gid=GA1.3.207092622.1560818247; ads-disabled=0; _dc_gtm_UA-45693420-4=1; _dc_gtm_UA-45693420-14=1; __atuvc=42%7C25; __atuvs=5d09a711e4ca8c8e004',
    'token': '6112c32703f442f0',
}

data = '{"eventCode":"791021","runnerId":null,"searchString":null,"countryCode":null,"stateProvince":null,"city":null,"teamName":null,"gender":null,"ageFrom":null,"ageTo":null,"overallPlaceFrom":"10000","overallPlaceTo":null,"paceFrom":null,"paceTo":null,"overallTimeFrom":null,"overallTimeTo":null,"gunTimeFrom":null,"gunTimeTo":null,"ageGradedTimeFrom":null,"ageGradedTimeTo":null,"ageGradedPlaceFrom":null,"ageGradedPlaceTo":null,"ageGradedPerformanceFrom":null,"ageGradedPerformanceTo":null,"handicap":null,"sortColumn":"overallTime","sortDescending":false,"pageIndex":1,"pageSize":5000}'

response = requests.post('https://results.nyrr.org/api/runners/finishers-filter', headers=headers, data=data)
df = pd.DataFrame(response.json()['response']['items'])
df
# Out:
#      age  ageGradePercent  ageGradePlace ageGradeTime      bib birthdate  \
# 0     49             43.4         1982.0        51:36  1622178      None
# 1     48             43.1         1983.0        53:56  1622179      None
# 2     34             43.7          499.0        17:05  1622180      None
# 3     40             40.6         1984.0        11:53  1622181      None
# 4     63             49.1           61.0        18:07  1622182      None
# 5     42             41.2         1985.0        07:41  1622183      None
# 6     31             43.7          500.0        17:25  1622184      None
# 7     46             42.4         1986.0        58:53  1622185      None
# 8     42             41.2         1987.0        07:47  1622186      None
# 9     45             42.1         1988.0        01:09  1622187      None
# 10    29             39.9         2053.0        17:36  1622188      None
# 11    27             43.7          398.0        17:37  1622189      None
# ...
