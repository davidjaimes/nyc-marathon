# %%
import requests
import pandas

headers = {
    'origin': 'https://results.nyrr.org',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9',
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'content-type': 'application/json;charset=UTF-8',
    'accept': 'application/json, text/plain, */*',
    'referer': 'https://results.nyrr.org/event/700913/finishers',
    'authority': 'results.nyrr.org',
    'cookie': '__cfduid=de36b16bb4d0acc47786cf2b9997d54d71560818244; _gcl_au=1.1.1592280569.1560818247; _ga=GA1.2.190767401.1560818247; _gid=GA1.2.207092622.1560818247; _fbp=fb.1.1560818247391.393523298; ARRAffinity=851d7f30361f6d0723ca121b2bd6d6718ac17eb6e82712885034bbf6fcabc392; _ga=GA1.3.190767401.1560818247; _gid=GA1.3.207092622.1560818247; ads-disabled=0; _dc_gtm_UA-45693420-4=1; _dc_gtm_UA-45693420-14=1; __atuvc=18%7C25; __atuvs=5d084f2e8e8264cb001',
    'token': '6112c32703f442f0',
}

data = '{"eventCode":"700913","runnerId":null,"searchString":null,"handicap":null,"sortColumn":"overallTime","sortDescending":false,"pageIndex":1,"pageSize":56}'

response = requests.post('https://results.nyrr.org/api/runners/finishers-filter', headers=headers, data=data)

# %%
json = response.json()['response']
pandas.DataFrame(json['items'])
# Out:
#     age  ageGradePercent  ageGradePlace ageGradeTime      bib birthdate  \
# 0    30             83.6              1        31:39  1207652      None
# 1    19             81.4              2        35:44  1207653      None
# 2    35             79.6              3        39:19  1207654      None
# 3    35             77.2              4        44:09  1207655      None
# 4    50             84.5              1        29:57  1207656      None
# 5    35             76.5              5        45:38  1207657      None
# 6    35             75.2              6        48:35  1207658      None
# 7    35             74.6              7        49:50  1207659      None
# 8    35             74.1              8        51:04  1207660      None
# 9    26             73.3              1        52:59  1207661      None
# 10   25             72.2              2        55:33  1207662      None
# 11   35             72.0              9        55:59  1207663      None
# ...
